# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\DAMILOLA-PC\Desktop\python\examination_cleaned.csv")

# %%
df
# Out:
#      Gender    Caste coaching Class_ten_education twelve_education   medium  \
# 0      male  General       NO                SEBA            AHSEC  ENGLISH
# 1      male      OBC       WA                SEBA            AHSEC   OTHERS
# 2      male      OBC       OA              OTHERS             CBSE  ENGLISH
# 3      male  General       WA                SEBA            AHSEC   OTHERS
# 4      male  General       OA                SEBA             CBSE  ENGLISH
# ..      ...      ...      ...                 ...              ...      ...
# 617  female       ST       WA                SEBA             CBSE  ENGLISH
# 618  female       ST       WA                SEBA            AHSEC  ENGLISH
# 619    male       ST       WA                SEBA            AHSEC  ENGLISH
# 620    male       ST       WA                SEBA             CBSE  ENGLISH
# 621  female       ST       NO                SEBA             CBSE  ENGLISH
#
# ...

# %%
df.head()
# Out:
#   Gender    Caste coaching Class_ten_education twelve_education   medium  \
# 0   male  General       NO                SEBA            AHSEC  ENGLISH
# 1   male      OBC       WA                SEBA            AHSEC   OTHERS
# 2   male      OBC       OA              OTHERS             CBSE  ENGLISH
# 3   male  General       WA                SEBA            AHSEC   OTHERS
# 4   male  General       OA                SEBA             CBSE  ENGLISH
#
#    Class_X_Percentage  Class_XII_Percentage Father_occupation  \
# 0                  90                    90            DOCTOR
# 1                  90                    90    SCHOOL_TEACHER
# 2                  90                    90          BUSINESS
# 3                  90                    90    SCHOOL_TEACHER
# 4                  90                    90   COLLEGE_TEACHER
#
#   Mother_occupation time Performance
# 0            OTHERS  ONE   Excellent
# 1        HOUSE_WIFE  TWO   Excellent
# 2        HOUSE_WIFE  TWO   Excellent
# ...

# %%
df.tail()
# Out:
#      Gender Caste coaching Class_ten_education twelve_education   medium  \
# 617  female    ST       WA                SEBA             CBSE  ENGLISH
# 618  female    ST       WA                SEBA            AHSEC  ENGLISH
# 619    male    ST       WA                SEBA            AHSEC  ENGLISH
# 620    male    ST       WA                SEBA             CBSE  ENGLISH
# 621  female    ST       NO                SEBA             CBSE  ENGLISH
#
#      Class_X_Percentage  Class_XII_Percentage Father_occupation  \
# 617                  70                    80            DOCTOR
# 618                  70                    80            OTHERS
# 619                  80                    70        CULTIVATOR
# 620                  70                    80            OTHERS
# 621                  80                    70          BUSINESS
#
#     Mother_occupation   time Performance
# 617    SCHOOL_TEACHER    TWO     Average
# 618        HOUSE_WIFE    ONE     Average
# ...

# %%
df.isnull().sum()
# Out:
# Gender                  0
# Caste                   0
# coaching                0
# Class_ten_education     0
# twelve_education        0
# medium                  0
# Class_X_Percentage      0
# Class_XII_Percentage    0
# Father_occupation       0
# Mother_occupation       0
# time                    0
# Performance             0
# dtype: int64

# %% [markdown]
# What is the distribution of students by gender?

# %%
gender_distribution = df['Gender'].value_counts()

# %%
plt.figure(figsize=(6, 4))
gender_distribution.plot(kind='bar', color=['blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Number of Students')
plt.title('Distribution of Students by Gender')
plt.xticks(rotation=0)
plt.show()

# %%
print(gender_distribution)
# Out:
# Gender
# male      334
# female    288
# Name: count, dtype: int64

# %% [markdown]
# What percentage of students belong to each caste category?

# %%
caste_distribution = df['Caste'].value_counts(normalize=True) * 100

# %%
plt.figure(figsize=(6, 6))
caste_distribution.plot(kind='pie', autopct='%1.1f%%', cmap='Set3', startangle=140)
plt.title('Percentage of Students by Caste Category')
plt.ylabel('')  # Hide y-label for better visualization
plt.show()

# %% [markdown]
# How many students attended coaching classes?

# %%
coaching_counts = df['coaching'].value_counts()

# %%
plt.figure(figsize=(6, 4))
coaching_counts.plot(kind='bar', color=['green', 'red', 'blue', 'orange'])
plt.xlabel('Coaching Attendance')
plt.ylabel('Number of Students')
plt.title('Number of Students Attending Coaching Classes')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ###Academic Performance:

# %% [markdown]
# What is the average Class 10 and Class 12 percentage of students?

# %%
coaching_avg = df.groupby('coaching')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

print("Average Class 10 and Class 12 Percentage by Coaching Attendance:")
print(coaching_avg)
# Out:
# Average Class 10 and Class 12 Percentage by Coaching Attendance:
#           Class_X_Percentage  Class_XII_Percentage
# coaching
# NO                 85.555556             84.236111
# OA                 87.692308             85.692308
# WA                 86.610169             84.019370

# %%
gender_avg = df.groupby('Gender')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

print("\nAverage Class 10 and Class 12 Percentage by Gender:")
print(gender_avg)
# Out:
# Average Class 10 and Class 12 Percentage by Gender:
#         Class_X_Percentage  Class_XII_Percentage
# Gender
# female           87.500000             85.208333
# male             85.598802             83.413174

# %%
# Calculate average percentages based on caste
caste_avg = df.groupby('Caste')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

print("\nAverage Class 10 and Class 12 Percentage by Caste:")
print(caste_avg)
# Out:
# Average Class 10 and Class 12 Percentage by Caste:
#          Class_X_Percentage  Class_XII_Percentage
# Caste
# General           87.591973             85.785953
# OBC               86.753247             84.480519
# SC                86.969697             84.696970
# ST                82.524272             79.126214

# %%
# Calculate average percentages based on father's occupation
father_occ_avg = df.groupby('Father_occupation')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

# Calculate average percentages based on mother's occupation
mother_occ_avg = df.groupby('Mother_occupation')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

print("\nAverage Class 10 and Class 12 Percentage by Father's Occupation:")
print(father_occ_avg)

print("\nAverage Class 10 and Class 12 Percentage by Mother's Occupation:")
print(mother_occ_avg)
# Out:
# Average Class 10 and Class 12 Percentage by Father's Occupation:
#                    Class_X_Percentage  Class_XII_Percentage
# Father_occupation
# BANK_OFFICIAL               87.619048             84.285714
# BUSINESS                    85.643564             83.564356
# COLLEGE_TEACHER             87.777778             85.925926
# CULTIVATOR                  82.692308             80.384615
# DOCTOR                      88.518519             88.518519
# ENGINEER                    88.888889             86.888889
# OTHERS                      86.584362             84.074074
# SCHOOL_TEACHER              85.333333             82.476190
#
# Average Class 10 and Class 12 Percentage by Mother's Occupation:
#                    Class_X_Percentage  Class_XII_Percentage
# Mother_occupation
# BANK_OFFICIAL               90.000000             85.000000
# BUSINESS                    90.000000             83.333333
# COLLEGE_TEACHER             89.473684             88.947368
# ...

# %%
performance_avg = df.groupby('Performance')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

print("\nAverage Class 10 and Class 12 Percentage by Performance Category:")
print(performance_avg)
# Out:
# Average Class 10 and Class 12 Percentage by Performance Category:
#              Class_X_Percentage  Class_XII_Percentage
# Performance
# Average               83.815789             80.526316
# Excellent             87.551020             86.326531
# Good                  86.958763             84.381443
# Vg                    87.640449             86.123596

# %%
performance_avg = df.groupby('Performance')[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

print("\nAverage Class 10 and Class 12 Percentage by Performance Category:")
print(performance_avg)
# Out:
# Average Class 10 and Class 12 Percentage by Performance Category:
#              Class_X_Percentage  Class_XII_Percentage
# Performance
# Average               83.815789             80.526316
# Excellent             87.551020             86.326531
# Good                  86.958763             84.381443
# Vg                    87.640449             86.123596

# %%
def plot_avg_bar_chart(group_by_column, title):
    avg_scores = df.groupby(group_by_column)[['Class_X_Percentage', 'Class_XII_Percentage']].mean()

    avg_scores.plot(kind='bar', figsize=(8, 5), colormap='viridis')
    plt.xlabel(group_by_column)
    plt.ylabel('Average Percentage')
    plt.title(title)
    plt.xticks(rotation=45)
    plt.legend(['Class 10', 'Class 12'])
    plt.show()

# %%
plot_avg_bar_chart('coaching', 'Average Class 10 & 12 Percentage by Coaching Attendance')
plot_avg_bar_chart('Gender', 'Average Class 10 & 12 Percentage by Gender')
plot_avg_bar_chart('Caste', 'Average Class 10 & 12 Percentage by Caste')
plot_avg_bar_chart('Father_occupation', 'Average Class 10 & 12 Percentage by Father\'s Occupation')
plot_avg_bar_chart('Mother_occupation', 'Average Class 10 & 12 Percentage by Mother\'s Occupation')
plot_avg_bar_chart('Performance', 'Average Class 10 & 12 Percentage by Performance Category')

# %% [markdown]
# ### What is the average Class X and Class XII percentage for students?

# %%
performance_counts = df["Performance"].value_counts()
performance_counts
# Out:
# Performance
# Good         194
# Vg           178
# Average      152
# Excellent     98
# Name: count, dtype: int64

# %%
coaching_performance = df.groupby("coaching")["Class_XII_Percentage"].mean()
coaching_performance
# Out:
# coaching
# NO    84.236111
# OA    85.692308
# WA    84.019370
# Name: Class_XII_Percentage, dtype: float64

# %%
gender_comparison = df.groupby("Gender")[["Class_X_Percentage", "Class_XII_Percentage"]].mean()
gender_comparison
# Out:
#         Class_X_Percentage  Class_XII_Percentage
# Gender
# female           87.500000             85.208333
# male             85.598802             83.413174

# %%
father_effect = df.groupby("Father_occupation")["Class_XII_Percentage"].mean()
mother_effect = df.groupby("Mother_occupation")["Class_XII_Percentage"].mean()

father_effect, mother_effect
# Out:
# (Father_occupation
#  BANK_OFFICIAL      84.285714
#  BUSINESS           83.564356
#  COLLEGE_TEACHER    85.925926
#  CULTIVATOR         80.384615
#  DOCTOR             88.518519
#  ENGINEER           86.888889
#  OTHERS             84.074074
#  SCHOOL_TEACHER     82.476190
#  Name: Class_XII_Percentage, dtype: float64,
#  Mother_occupation
#  BANK_OFFICIAL      85.000000
#  BUSINESS           83.333333
#  COLLEGE_TEACHER    88.947368
#  CULTIVATOR         80.000000
#  DOCTOR             89.230769
#  ENGINEER           90.000000
#  HOUSE_WIFE         83.464373
#  OTHERS             83.970588
#  SCHOOL_TEACHER     85.865385
#  Name: Class_XII_Percentage, dtype: float64)

# %%
caste_performance = df.groupby("Caste")["Class_XII_Percentage"].mean()
caste_performance
# Out:
# Caste
# General    85.785953
# OBC        84.480519
# SC         84.696970
# ST         79.126214
# Name: Class_XII_Percentage, dtype: float64

# %%
caste_performance = df.groupby("Caste")["Class_XII_Percentage"].mean()
caste_performance
# Out:
# Caste
# General    85.785953
# OBC        84.480519
# SC         84.696970
# ST         79.126214
# Name: Class_XII_Percentage, dtype: float64

# %%
correlation = df["Class_X_Percentage"].corr(df["Class_XII_Percentage"])
correlation
# Out:
# 0.637613008851513

# %% [markdown]
# ### Is there a correlation between attending coaching classes and performance?

# %%
# Create a boxplot to visualize coaching vs performance
plt.figure(figsize=(8, 5))
sns.boxplot(x=df["coaching"], y=df["Class_XII_Percentage"], palette="coolwarm")
# Out:
# C:\Users\DAMILOLA-PC\AppData\Local\Temp\ipykernel_8804\2136022455.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["coaching"], y=df["Class_XII_Percentage"], palette="coolwarm")
# <Axes: xlabel='coaching', ylabel='Class_XII_Percentage'>
